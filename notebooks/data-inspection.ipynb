# %%
import pandas as pd

# %%
# load data
player_data = "../data/processed/player_data.csv"
team_data = "../data/processed/team_data.csv"

def load_data(team_loc, player_loc):
    
    return pd.read_csv(team_loc), pd.read_csv(player_loc)

team_df, player_df = load_data(team_loc=team_data, player_loc=player_data)

# %%
NBA_TEAMS = list(set(list(team_df["teamName"])))

# %%
ROOT_DATA_DIR = "../data/insights"

# %% [markdown]
# ### Team Data
# This data shows each individual team from each individual game in the 2022-2023 season, and tracks the calls from the L2M report.
# > `teamName` is the team that benefits from "callsReceived" or "errorsInFavor" for a given row.

# %%
team_df
# Out:
#      Unnamed: 0       teamName       opponent                    game  \
# 0             0          76ers        Nuggets        76ers vs Nuggets
# 1             1        Nuggets          76ers         Nuggets @ 76ers
# 2             2        Pistons        Rockets      Pistons vs Rockets
# 3             3        Rockets        Pistons       Rockets @ Pistons
# 4             4          Spurs           Suns           Spurs vs Suns
# ..          ...            ...            ...                     ...
# 549         549        Thunder   Timberwolves  Thunder @ Timberwolves
# 550         550           Suns      Mavericks       Suns vs Mavericks
# 551         551      Mavericks           Suns        Mavericks @ Suns
# 552         552          Kings  Trail Blazers  Kings vs Trail Blazers
# 553         553  Trail Blazers          Kings   Trail Blazers @ Kings
#
#        gameId          gameDate  pointsScored  pointsAllowed outcome  \
# 0    22200741  January 28, 2023           126            119     WON
# 1    22200741  January 28, 2023           119            126    LOSS
# 2    22200743  January 28, 2023           114            117    LOSS
# 3    22200743  January 28, 2023           117            114     WON
# 4    22200748  January 28, 2023           118            128    LOSS
# ..        ...               ...           ...            ...     ...
# 549  22200010  October 19, 2022           108            115    LOSS
# 550  22200013  October 19, 2022           107            105     WON
# 551  22200013  October 19, 2022           105            107    LOSS
# 552  22200014  October 19, 2022           108            115    LOSS
# 553  22200014  October 19, 2022           115            108     WON
#
#      callsReceived  errorsInFavor  posessionsInFavor
# 0                1              1                  0
# 1                0              0                  0
# 2                4              0                  0
# 3                0              0                  0
# 4                1              0                  0
# ..             ...            ...                ...
# 549              0              1                  0
# 550              2              0                  0
# 551              0              1                  0
# 552              7              1                  0
# 553              0              0                  0
#
# [554 rows x 12 columns]

# %% [markdown]
# ### Player Data
# This data is a scrape of each individual L2M report, tracking the specific call, decision and players involved in the last two minutes of NBA games.
# > `disadvantagedPlayer` is not always a "victim". In the case of an `Incorrect Call` the committingPlayer is disadvantaged

# %%
player_df
# Out:
#       Unnamed: 0         id committingPlayer       disadvantagedPlayer  \
# 0              0  1535-2110      P.J. Tucker              Nikola Jokic
# 1              1  1535-2111      P.J. Tucker              Nikola Jokic
# 2              2  1535-2112      P.J. Tucker              Nikola Jokic
# 3              3  1536-2113     Aaron Gordon               Joel Embiid
# 4              4  1537-2114     James Harden  Kentavious Caldwell-Pope
# ...          ...        ...              ...                       ...
# 6828        6828  1545-2191        Josh Hart             Kevin Huerter
# 6829        6829  1546-2192     De'Aaron Fox            Damian Lillard
# 6830        6830  1547-2193     Jerami Grant                Malik Monk
# 6831        6831  1547-2194  Anfernee Simons             Kevin Huerter
# 6832        6832  1548-2195    Terence Davis              Jerami Grant
#
#             callType          decision     time teamInPosession  difficulty  \
# 0     Foul: Personal  Correct Non-Call    01:59         Nuggets  Observable
# 1     Foul: Personal  Correct Non-Call    01:54         Nuggets  Observable
# 2     Foul: Shooting  Correct Non-Call  01:52.6         Nuggets  Observable
# 3     Foul: Shooting  Correct Non-Call  01:35.8           76ers  Observable
# 4     Foul: Shooting  Correct Non-Call  01:28.1         Nuggets  Observable
# ...              ...               ...      ...             ...         ...
# 6828  Foul: Shooting  Correct Non-Call  00:16.5           Kings  Observable
# 6829  Foul: Personal      Correct Call  00:14.1   Trail Blazers  Observable
# 6830  Foul: Personal      Correct Call  00:11.4           Kings  Observable
# 6831  Foul: Shooting  Correct Non-Call  00:09.4           Kings  Observable
# 6832  Foul: Personal      Correct Call  00:04.6   Trail Blazers  Observable
#
#                                                 comment
# 0     Tucker (PHI) and Jokic (DEN) engage and diseng...
# 1     Tucker (PHI) establishes a legal guarding posi...
# 2     Tucker (PHI) brings his left arm forward sligh...
# 3     Gordon (DEN) jumps vertically and incidental b...
# 4     Harden (PHI) legally contests Caldwell-Pope&ap...
# ...                                                 ...
# 6828  Hart (POR) legally contests Huerter?s (SAC) ju...
# 6829    Fox (SAC) commits a take foul on Lillard (POR).
# 6830  Grant (POR) places two hands on Fox (SAC) and ...
# 6831  Simons (POR) maintains a legal guarding positi...
# 6832  Davis (SAC) makes contact to Grant's (POR) arm...
#
# [6833 rows x 10 columns]

# %% [markdown]
# ### Exploring Team Data

# %%
aggregated_favorable_errors = team_df.groupby("teamName")["errorsInFavor"].sum().sort_values(ascending=False)
aggregated_favorable_errors = aggregated_favorable_errors.to_frame().reset_index()

# %% [markdown]
# ### Which teams have benefited from the most errors?

# %%
aggregated_favorable_errors.head(32)
# Out:
#          teamName  errorsInFavor
# 0       Mavericks             22
# 1       Cavaliers             21
# 2          Lakers             20
# 3           76ers             20
# 4          Pacers             19
# 5            Heat             18
# 6         Thunder             18
# 7         Celtics             17
# 8        Warriors             17
# 9         Hornets             17
# 10          Hawks             15
# 11        Raptors             15
# 12        Pistons             14
# 13        Nuggets             14
# 14         Knicks             14
# 15          Kings             14
# 16       Clippers             12
# 17          Spurs             12
# 18   Timberwolves             12
# 19  Trail Blazers             12
# 20           Nets             11
# 21          Bulls             11
# 22      Grizzlies             11
# 23          Bucks             10
# 24       Pelicans             10
# 25          Magic              9
# 26        Rockets              9
# 27           Suns              9
# 28           Jazz              7
# 29        Wizards              7

# %%
victim_teams = team_df.groupby("opponent")["errorsInFavor"].sum().sort_values(ascending=False)
victim_teams = victim_teams.to_frame().reset_index()
victim_teams.rename(columns={"errorsInFavor": "errorsAgainst", "opponent": "teamName"}, inplace=True)

# %% [markdown]
# ### Which teams have experienced the most incorrect calls go against them?

# %%
victim_teams.head(32)
# Out:
#          teamName  errorsAgainst
# 0       Mavericks             26
# 1         Nuggets             23
# 2           Kings             21
# 3          Pacers             20
# 4            Heat             17
# 5           76ers             17
# 6            Nets             16
# 7         Hornets             16
# 8         Celtics             16
# 9          Knicks             16
# 10      Cavaliers             16
# 11   Timberwolves             15
# 12           Jazz             14
# 13         Lakers             14
# 14        Thunder             14
# 15          Bulls             13
# 16          Bucks             13
# 17  Trail Blazers             12
# 18          Hawks             12
# 19        Raptors             12
# 20       Warriors             12
# 21       Pelicans             11
# 22        Pistons             11
# 23          Spurs             11
# 24           Suns             11
# 25      Grizzlies              9
# 26          Magic              9
# 27       Clippers              7
# 28        Wizards              7
# 29        Rockets              6

# %%
combined = pd.merge(aggregated_favorable_errors, victim_teams, how="outer", on="teamName")
combined["errorDelta"] = combined["errorsInFavor"] - combined["errorsAgainst"]
combined = combined.sort_values(by="errorDelta").reset_index()
del combined["index"]

# %% [markdown]
# ### Examining the difference between favorable and unfavorable calls show which teams have experienced the largest delta.

# %%
combined.head(32)
# Out:
#          teamName  errorsInFavor  errorsAgainst  errorDelta
# 0         Nuggets             14             23          -9
# 1           Kings             14             21          -7
# 2            Jazz              7             14          -7
# 3            Nets             11             16          -5
# 4       Mavericks             22             26          -4
# 5           Bucks             10             13          -3
# 6    Timberwolves             12             15          -3
# 7            Suns              9             11          -2
# 8           Bulls             11             13          -2
# 9          Knicks             14             16          -2
# 10       Pelicans             10             11          -1
# 11         Pacers             19             20          -1
# 12  Trail Blazers             12             12           0
# 13          Magic              9              9           0
# 14        Wizards              7              7           0
# 15          Spurs             12             11           1
# 16           Heat             18             17           1
# 17        Hornets             17             16           1
# 18        Celtics             17             16           1
# 19      Grizzlies             11              9           2
# 20          76ers             20             17           3
# 21        Pistons             14             11           3
# 22        Raptors             15             12           3
# 23        Rockets              9              6           3
# 24          Hawks             15             12           3
# 25        Thunder             18             14           4
# 26       Clippers             12              7           5
# 27       Warriors             17             12           5
# 28      Cavaliers             21             16           5
# 29         Lakers             20             14           6

# %%
combined.to_csv(f"{ROOT_DATA_DIR}/team_errors.csv")

# %% [markdown]
# ## Exploring Player Data

# %%
aggregated_disadvantaged_player_decisions = player_df.loc[player_df["decision"] == "Incorrect Non-Call"].groupby(["disadvantagedPlayer", "decision"])["callType"].count().sort_values(ascending=False)
aggregated_disadvantaged_player_decisions = aggregated_disadvantaged_player_decisions.to_frame().reset_index()
aggregated_disadvantaged_player_decisions.rename(columns={"callType": "callCount"}, inplace=True)

# %%
players_only = aggregated_disadvantaged_player_decisions[
    ~aggregated_disadvantaged_player_decisions["disadvantagedPlayer"].isin(NBA_TEAMS)
].reset_index()
teams_only = aggregated_disadvantaged_player_decisions[
    aggregated_disadvantaged_player_decisions["disadvantagedPlayer"].isin(NBA_TEAMS)
]
del players_only["index"]

# %% [markdown]
# ### The top 50 most disadvantaged players - the players who have had the most Incorrect Non-Calls go against them

# %%
players_only.head(50)
# Out:
#          disadvantagedPlayer            decision  callCount
# 0           Donovan Mitchell  Incorrect Non-Call          6
# 1               De'Aaron Fox  Incorrect Non-Call          5
# 2    Shai Gilgeous-Alexander  Incorrect Non-Call          5
# 3            Lauri Markkanen  Incorrect Non-Call          4
# 4               Nikola Jokic  Incorrect Non-Call          4
# 5             Scottie Barnes  Incorrect Non-Call          4
# 6              DeMar DeRozan  Incorrect Non-Call          4
# 7          Tyrese Haliburton  Incorrect Non-Call          4
# 8                Jalen Green  Incorrect Non-Call          3
# 9                Joel Embiid  Incorrect Non-Call          3
# 10              Jimmy Butler  Incorrect Non-Call          3
# 11              Jaylen Brown  Incorrect Non-Call          3
# 12               Luka Doncic  Incorrect Non-Call          3
# 13            Keldon Johnson  Incorrect Non-Call          3
# 14             Jarrett Allen  Incorrect Non-Call          3
# 15  Kentavious Caldwell-Pope  Incorrect Non-Call          3
# 16     Giannis Antetokounmpo  Incorrect Non-Call          3
# 17              Jordan Poole  Incorrect Non-Call          3
# 18        Bennedict Mathurin  Incorrect Non-Call          3
# 19            Christian Wood  Incorrect Non-Call          3
# 20             Kevin Huerter  Incorrect Non-Call          2
# 21             Julius Randle  Incorrect Non-Call          2
# 22             Yuta Watanabe  Incorrect Non-Call          2
# 23        Karl-Anthony Towns  Incorrect Non-Call          2
# 24            Wenyen Gabriel  Incorrect Non-Call          2
# 25              Tyrese Maxey  Incorrect Non-Call          2
# 26              Torrey Craig  Incorrect Non-Call          2
# 27              Kelly Olynyk  Incorrect Non-Call          2
# 28          Tim Hardaway Jr.  Incorrect Non-Call          2
# 29              Kevin Durant  Incorrect Non-Call          2
# 30         Mitchell Robinson  Incorrect Non-Call          2
# 31              Terry Rozier  Incorrect Non-Call          2
# 32         Marcus Morris Sr.  Incorrect Non-Call          2
# 33              Kyrie Irving  Incorrect Non-Call          2
# 34         Spencer Dinwiddie  Incorrect Non-Call          2
# 35              LeBron James  Incorrect Non-Call          2
# 36             Luguentz Dort  Incorrect Non-Call          2
# 37            Quentin Grimes  Incorrect Non-Call          2
# 38            Paolo Banchero  Incorrect Non-Call          2
# 39           P.J. Washington  Incorrect Non-Call          2
# 40              Aaron Gordon  Incorrect Non-Call          2
# 41              Myles Turner  Incorrect Non-Call          2
# 42            Onyeka Okongwu  Incorrect Non-Call          2
# 43           Josh Richardson  Incorrect Non-Call          2
# 44          Domantas Sabonis  Incorrect Non-Call          2
# 45                 Ja Morant  Incorrect Non-Call          2
# 46            Darius Garland  Incorrect Non-Call          2
# 47            Damian Lillard  Incorrect Non-Call          2
# 48              John Collins  Incorrect Non-Call          2
# 49               Cory Joseph  Incorrect Non-Call          2

# %%
players_only.to_csv(f"{ROOT_DATA_DIR}/player_incorrect_non_calls.csv")

# %%
aggregated_committing_player_decisions = player_df.loc[player_df["decision"] == "Incorrect Call"].groupby(["committingPlayer", "decision"])["callType"].count().sort_values(ascending=False)
aggregated_committing_player_decisions = aggregated_committing_player_decisions.to_frame().reset_index()
committing_players_only = aggregated_committing_player_decisions[
    ~aggregated_committing_player_decisions["committingPlayer"].isin(NBA_TEAMS)
].reset_index()
committing_players_only.rename(columns={"callType": "callCount"}, inplace=True)
del committing_players_only["index"]

# %% [markdown]
# ### The top 50 most disadvantaged players - the players who have had the most Incorrect Calls called against them

# %%
committing_players_only.head(50)
# Out:
#            committingPlayer        decision  callCount
# 0              Jusuf Nurkic  Incorrect Call          2
# 1              Jimmy Butler  Incorrect Call          2
# 2   Shai Gilgeous-Alexander  Incorrect Call          2
# 3         Kenyon Martin Jr.  Incorrect Call          1
# 4             Klay Thompson  Incorrect Call          1
# 5           Lauri Markkanen  Incorrect Call          1
# 6              LeBron James  Incorrect Call          1
# 7             Mikal Bridges  Incorrect Call          1
# 8               Paul George  Incorrect Call          1
# 9                Al Horford  Incorrect Call          1
# 10               Josh Green  Incorrect Call          1
# 11        Russell Westbrook  Incorrect Call          1
# 12                Saben Lee  Incorrect Call          1
# 13               Saddiq Bey  Incorrect Call          1
# 14           Scottie Barnes  Incorrect Call          1
# 15           T.J. McConnell  Incorrect Call          1
# 16         Tim Hardaway Jr.  Incorrect Call          1
# 17               Trae Young  Incorrect Call          1
# 18             Usman Garuba  Incorrect Call          1
# 19           Reggie Bullock  Incorrect Call          1
# 20             Jordan Poole  Incorrect Call          1
# 21          Anthony Edwards  Incorrect Call          1
# 22              Joel Embiid  Incorrect Call          1
# 23       Bennedict Mathurin  Incorrect Call          1
# 24        Bogdan Bogdanovic  Incorrect Call          1
# 25            Cameron Payne  Incorrect Call          1
# 26             Caris LeVert  Incorrect Call          1
# 27           Christian Wood  Incorrect Call          1
# 28         D'Angelo Russell  Incorrect Call          1
# 29          Devonte' Graham  Incorrect Call          1
# 30            Dillon Brooks  Incorrect Call          1
# 31      Dorian Finney-Smith  Incorrect Call          1
# 32            Edmond Sumner  Incorrect Call          1
# 33            Fred VanVleet  Incorrect Call          1
# 34           Grant Williams  Incorrect Call          1
# 35            Grayson Allen  Incorrect Call          1
# 36            Jalen Brunson  Incorrect Call          1
# 37            Jalen Johnson  Incorrect Call          1
# 38          Jalen McDaniels  Incorrect Call          1
# 39             Jerami Grant  Incorrect Call          1
# 40          Wesley Matthews  Incorrect Call          1

# %%
committing_players_only.to_csv(f"{D}/player_incorrect_fouls.csv")
